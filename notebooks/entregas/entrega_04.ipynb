# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel64bit/distribuicao-renovavel/blob/dev/notebooks/entregas/entrega_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2024/02**
#
#
# # **Entrega 4**
#
# ---

# %% [markdown]
# # **Titulo do Projeto**:
# Projeção de Demanda de Energia Elétrica e Recomendações de Distribuição de Fontes Renováveis por Região e Subsistema de Energia Brasileiro
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Daniel Rodrigues da Silva, 10408578' #@param {type:"string"}
Aluno2 = 'João Pedro Barreto de Melo, 10368968' #@param {type:"string"}
Aluno3 = 'Julia Rodrigues da Cunha, 10407164' #@param {type:"string"}
Aluno4 = 'Rafael Rodrigues Nascimento, 10370240 ' #@param {type:"string"}
Aluno5 = 'Samuel Regis Nascimento Barbosa, 10369514' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
#
# O desenvolvimento de energia renovável no Brasil vem se tornando cada vez mais necessário no contexto atual, impulsionado pelo aumento da população, urbanização, expansão tecnológica, industrial e comercial, além das mudanças climáticas provocadas pelos gases poluentes. De acordo com o Plano Decenal de Energia 2020-2029, gerado pela Empresa de Pesquisa Energética, a demanda por energia elétrica no Brasil poderá ter um acréscimo anual de 3,5% nesses anos. Com esse aumento de consumo excessivo e ininterrupto tornou-se imprescindível a necessidade de fontes energéticas mais limpas e renováveis no país.
#
# Fontes de energias renováveis são um grupo considerado inesgotáveis e limpos, uma vez que suas quantidades se renovam constantemente mesmo sendo usadas, e ainda, emitem menos gases de efeito estufa (GEE). Por exemplo, fontes renováveis: hídrica (energia da água dos rios), solar (energia do sol), eólica (energia do vento), biomassa (energia de matéria orgânica), geotérmica (energia do interior da Terra) e oceânica (energia das marés e das ondas) (EPE, 2022).
#
# Diante disso, o propósito deste projeto é desenvolver um sistema, capaz de identificar áreas de atuação de distribuidoras de energia afim de gerar um modelo de recomendações de energias renováveis, com base nas regiões e subsistemas brasileiros. Para alcançar isso, o projeto empregará técnicas avançadas de análise de series temporais e modelagem preditiva, para prever a demanda de energia e avaliar a capacidade de geração renovável, para desenvolver o sistema de recomendação.
#
# Assim, podemos promover o uso eficiente de fontes renováveis, proporcionando uma solução que, não apenas responda as demandas energéticas, mas também alinhe a produção de energia com os principais tipos de sustentabilidade e de sua eficiência. Além de permitir uma distribuição mais eficiente de recursos e uma redução nos custos de geração e transmissão de energia e a mitigação das mudanças climáticas.
#
# Cada região do Brasil possui características geográficas e climáticas únicas que influenciam a viabilidade e a eficiência das diferentes fontes renováveis. Essa diversidade se torna para aproveitar todos os diferentes tipos de fontes de energias renováveis, em diferentes territórios. Como no Nordeste, que devido aos ventos constantes e fortes e abundante radiação solar, ele possui grande potencial para a energia eólica e energia solar. A energia solar é a que mais cresce no Brasil (GOV, 2021).
#
# Na região Norte conta com uma grande extensão de florestas tropicais e rios, possibilitando a opção de energia e construção de usinas hidrelétricas. Sudeste e Sul, potencias para a energia eólica, e na região Centro-Oeste tem a capacidade de energia de biomassa e biogás, pois concentra uma parcela significativa de produção agrícola. Todas essas localidades são opções viáveis e eficientes.
#
# Em suma, é substancial que aproveitemos as características de cada região, diversificando a matriz energética e reduzindo a dependência de fontes não renováveis, assim nosso país poderá caminhar rumo ao futuro com mais energia limpa e sustentável.
#
# No Brasil, os números atestam que temos uma capacidade mais elevada de geração de energia limpa se comparado com outros países, com uma participação de 90% de energia proveniente de fontes renováveis (ONS, 2023).
#
# A nossa infraestrutura energética depende fortemente das energias hidrelétricas, e embora tenhamos uma parcela significativa de recursos por muitas décadas, ainda ficamos vulneráveis a secas, que são induzidas, principalmente, pelas mudanças climáticas do planeta.  Em vista disso, é crucial identificar a distribuição ideal de fontes de energia sustentáveis em diferentes regiões, assim conseguimos atender a demanda por eletricidade e, ainda, minimizar os impactos ambientais.
#
# A transição para fontes renováveis é fundamental para proteger os recursos naturais e combater o aquecimento global. Adicionalmente, essa transição pode apresentar benefícios econômicos, como a redução de custos de importação de combustíveis fósseis, sustentabilidade ambiental, melhoria da qualidade de vida das pessoas e o incremento da autonomia energética.
#
# O país dispõe de três subsistemas de energias principais: sistema interconectado, o sistema off-grid e o sistema isolado.
#
# O sistema interconectado compreende a rede nacional, que permite a transmissão de eletricidade por longas distâncias, é um sistema essencial para a garantia de energia estável e confiável em todo o Brasil. Para sua distribuição são necessários investimentos em infraestrutura de transmissão. Sistema off-grid, são energias descentralizadas, como paineis solares de telhado e pequenas turbinas eólicas, o utilizando reduzimos a dependência de combustíveis fósseis. Por fim, temos o sistema isolado, que atende em áreas remotas que dependem de geradores, integrando energias limpas nestes sistemas isolados podemos reduzir os custos e impactos ambientais.
#
# O potencial central que pretendemos resolver, é a capacidade de um sistema atual de previsão de demanda, que se adapta às flutuações e tendências emergentes no consumo de energia, e ajustar a subutilização de fontes renováveis devido à sua falta de recomendações otimizadas para a sua integração. Sem uma estratégia bem programada todos os recursos que possuímos serão inúteis.
#
# A previsão inadequada da demanda, pode levar a um desequilíbrio entre a oferta e demanda, resultando em um desperdício de energia e custos altíssimos para o sistema elétrico.  Portanto, um sistema de recomendação que combine previsões de demanda com sugestões para a melhor utilização de fontes renováveis poderá otimizar o consumo de energia e contribuir para um futuro mais sustentável

# %% [markdown]
# # **Referencial Teórico**
#
# No contexto da pesquisa acadêmica, o desenvolvimento de uma estrutura teórica abrangente é um componente crítico no estabelecimento da base para uma investigação robusta. Uma estrutura teórica serve para alinhar os objetivos da pesquisa com conceitos relevantes, que se integram na análise dos dados.
#
# A necessidade crescente de previsões de demanda de energia precisas, impulsionada pela integração de fontes de energia renováveis, tem motivado a pesquisa de diferentes técnicas de modelagem. Diversos trabalhos correlatos que investigaram abordagens para a previsão de demanda de energia elétrica serão analisados a seguir, contextualizando a presente pesquisa.
#
# O primeiro trabalho analisado, de Whitney e Mendonça (2022), explorou a aplicação da técnica LSTM (Long Short-Term Memory) para prever a demanda de energia de curto prazo, utilizando dados de potência coletados por um sistema SCADA de uma subestação elétrica. Os autores demonstraram a capacidade da LSTM de capturar a não linearidade inerente às séries temporais de demanda de energia, corroborando com a literatura que aponta a eficácia de RNAs para lidar com esse tipo de dado. A pesquisa utilizou dados reais de uma subestação, buscando otimizar a rede LSTM por meio de testes iterativos, fornecendo insights valiosos para a definição da metodologia do presente trabalho.
#
# O segundo trabalho, Alegre (2022), avaliou o desempenho de diferentes modelos para previsão de demanda de energia elétrica de curto prazo, utilizando uma série temporal diária de carga elétrica. O estudo comparou modelos como Holt-Winters, SARIMA, Prophet, Árvores de Decisão, XGBoost e LightGBM. Adicionalmente, o autor aplicou uma técnica de ensemble learning, combinando as previsões dos modelos individuais e obtendo resultados promissores, com o modelo ensemble apresentando o menor erro percentual absoluto médio (MAPE), de 1,60%. Essa pesquisa destaca a importância da comparação entre diferentes modelos para identificar a abordagem mais adequada para cada contexto específico.
#
# O terceiro trabalho, (IFTIKHAR et al., 2024), foi proposta uma nova técnica de ensemble de séries temporais para previsão de demanda de energia elétrica, combinando modelos estatísticos e de aprendizado de máquina. Diversas técnicas de previsão foram empregadas, incluindo modelos autorregressivos, de suavização exponencial, lineares, de regressão não linear e redes neurais. Essas técnicas visam criar uma forma mais confiável para modelagem e previsão. Os resultados indicaram que a abordagem de ensemble proposta foi eficiente e precisa, com um MAPE de 1,304%.
#
# A análise dos trabalhos mencionados demonstra que a escolha do modelo de previsão de demanda de energia depende das características dos dados e dos objetivos da pesquisa. A análise dos artigos revisados indicou que o uso de SARIMA para a previsão de demanda de energia elétrica demonstrou ser mais preciso e adequado em comparação com outras metodologias. Contudo, para o presente trabalho, optou-se por empregar a técnica Prophet. Esta escolha foi motivada pela sua capacidade de lidar com sazonalidades complexas e por sua flexibilidade na modelagem de dados. Espera-se que ajustes nos parâmetros do modelo Prophet (Facebook) possam otimizar a previsão, contribuindo de forma significativa para a resolução do problema em questão.

# %% [markdown]
# # **Diagrama de Solução**
#
# **Pré-processamento:**
#
# O pré-processamento é a etapa inicial e crucial em qualquer projeto de análise de dados ou aprendizado de máquina. Ele consiste em adequar os dados brutos para que estejam prontos para serem utilizados na fase de modelagem.
#
# No contexto do nosso projeto, o pré-processamento será fundamental para garantir a qualidade dos dados e prepará-los para os modelos de séries temporais e de aprendizado de máquina que utilizaremos.
#
# Objetivo: Adequar os dados brutos à análise, garantindo qualidade e formato adequado para modelagem. As três bases de dados serão pré-processadas individualmente antes da combinação.
#
# **Base 1: Consumo Mensal de Energia Elétrica**
#
# - Limpeza de Dados: Nesta etapa, os valores ausentes são identificados e tratados. A média será utilizada para colunas numéricas, como "Consumo" e "Consumidores", e a moda para colunas categóricas, como "Região", "Sistema" e "Classe". Valores discrepantes (outliers) que podem distorcer as análises também serão detectados e tratados, utilizando boxplots para visualizar e analisar a presença de outliers na coluna "Consumo".
#
# - Transformação de Dados: Os dados serão transformados para um formato adequado para análise. O formato das colunas de data será padronizado para o tipo datetime, permitindo análises temporais nas colunas "Data" e "DataExcel". Variáveis categóricas, como "Região", "Sistema", "Classe" e "TipoConsumidor", serão convertidas em variáveis dummy (0 ou 1).
#
# - Agregação de Dados: Valores agregados serão calculados em diferentes níveis de tempo, como o consumo total mensal de energia por Unidade Federativa (UF) e subsistema. Valores agregados também serão calculados para diferentes categorias, como a quantidade total de consumidores, subsistema e classe. Novas variáveis, como indicadores de sazonalidade ou tendências, serão criadas a partir das existentes
#
# O objetivo principal do pré-processamento é entregar dados limpos, consistentes e no formato ideal, permitindo que os modelos de aprendizado de máquina aprendam os padrões e gerem previsões precisas.

# %% [markdown]
# **Base 2: Capacidade Instalada de Geração**
#
# - Pré-processamento:
#     - Tipagem e características da tabela
#
# - Identificação de usinas com fontes renováveis ativas
#     - Conversão da unidade de geração de energia para MWh (Megawatt-hora)
# - Agregação de informações por usina
#     - Potência nominal (MW)
#     - Potência (MWh)
# - Visualização de dados
#     - Capacidade de geração por usina, Estado e subsistema elétrico
#     - Capacidade de geração por concessionária
# - Salvamento de arquivos
#     - Gravação de tabelas na camada refinada, conforme indica representação do pipeline

# %% [markdown]
# **Base 3: Dados comerciais de distribuidoras de energia**
#
# Inicialmente, foi realizada uma análise da base de dados da ANEEL, a qual revelou a presença de tipos de dados incorretos. As correções necessárias foram efetuadas para assegurar a integridade das informações. O mesmo procedimento foi realizado na base de dados do IBGE.
#
# As colunas que não seriam utilizadas foram removidas, considerando que a análise se concentraria na sumarização entre as UFs e os municípios das concessionárias. As duas bases de dados foram cruzadas para obter informações mais detalhadas sobre os municípios, utilizando as informações do IBGE. Uma tabela de agregação por UF foi criada, adicionando uma nova coluna que registrava a última ocorrência de cada concessionária no estado correspondente.
#
# Uma transformação de agrupamento (groupby transform) foi aplicada para manter apenas as concessionárias ativas até a data limite estipulada. Uma coluna adicional foi criada para sumarizar as concessionárias por UF, utilizando o mesmo método de agrupamento. Passos semelhantes foram realizados para criar uma coluna de agregação por município. No entanto, a tabela resultante por município não foi considerada relevante para a análise. Um gráfico de barras foi gerado para ilustrar a quantidade de concessionárias por UF, onde, pode-se observar que, em média, há 4 concessionárias por estado, com um mínimo de 1 e um máximo de 27, e uma mediana de 2.
#
#
# **Modelagem Preditiva:**
#
# Para lidar com a natureza temporal dos dados de consumo energético, propõe-se a utilização do modelo Prophet. Embora outros modelos, como ARIMA, SARIMA e Redes Neurais Recorrentes (RNNs), tenham sido mencionados, a escolha do Prophet se baseia em sua eficácia na modelagem de séries temporais com sazonalidade complexa e sua facilidade de uso para ajustes de parâmetros.
#
# A natureza temporal dos dados de consumo energético demanda a utilização de modelos capazes de capturar padrões complexos em sequências de dados. O modelo Prophet será empregado para prever a demanda futura de energia, considerando sua variação ao longo do tempo. A escolha do Prophet se justifica por sua capacidade de lidar com séries temporais que apresentam sazonalidade, um fator crucial na análise da demanda de energia elétrica.
#
# O Prophet se destaca por considerar a sazonalidade, incluindo sazonalidades múltiplas e que podem variar ao longo do tempo; por sua flexibilidade, que permite a inclusão de feriados e eventos especiais como variáveis; e por sua robustez a dados faltantes e outliers, características comuns em séries temporais de demanda de energia.
#
# Os parâmetros do modelo serão cuidadosamente ajustados para garantir a melhor adequação à base de dados e aos objetivos da pesquisa. Adicionalmente, será analisada a possibilidade de combinar o Prophet com outras técnicas de previsão, como o ensemble learning, visando aumentar a acurácia das previsões.
#
# Este pipeline visa desenvolver um sistema abrangente de recomendação de energias renováveis para o Brasil. O sucesso do projeto depende da qualidade dos dados, da escolha adequada do modelo e da interpretação precisa dos resultados. Espera-se que este sistema contribua para um futuro energético mais sustentável e eficiente no país.

# %% [markdown]
# ![pipeline_solucao.drawio-2.png](attachment:pipeline_solucao.drawio-2.png)
#
# Figura 1 - Representação do Pipeline.

# %% [markdown]
# # **EDA e Pré-processamento dos dados**
#
# Exploração e análise dos dados. Discussão e análise dos dados empregados (qualidade, limitações, simplicações ou recortes adotados etc.). Tarefas de preparação dos dados (transformações, compactação e encodes, junções de dados etc.).

# %% [markdown]
# ## 1. **ANEEL**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importação dos dados

df_dadoscomerciais = pd.read_csv('../../data/external/ANEEL/dados_comerciais/indger-dados-comerciais.csv', sep=";", encoding='latin1')
df_municipios = pd.read_excel('../../data/external/IBGE/RELATORIO_DTB_BRASIL_MUNICIPIO.xlsx')

# %%
# Análise inicial da base de dados da ANEEL
df_dadoscomerciais.head()
# Out:
#   DatGeracaoConjuntoDados        NumCNPJ SigAgente  \
# 0              2024-08-05  1229747000189   Cergapa
# 1              2024-08-05  1229747000189   Cergapa
# 2              2024-08-05  1229747000189   Cergapa
# 3              2024-08-05  1229747000189   Cergapa
# 4              2024-08-05  1229747000189   Cergapa
#
#                                   NomAgente NomTipoOutorga  \
# 0  COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# 1  COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# 2  COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# 3  COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# 4  COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
#
#   DatReferenciaInformada  CodMunicipioIBGE  QtdUCAtiva  QtdUCAtivaFat  \
# 0             2024-02-01           4202800         239            239
# 1             2024-01-01           4214904         108            108
# 2             2024-01-01           4206108        3642           3630
# ...

# %%
pd.set_option('display.max_rows', None)

print(f"""Tipo de dados:
{df_dadoscomerciais.dtypes}

Colunas:
{df_dadoscomerciais.columns}

Formato:
{df_dadoscomerciais.shape[0]} Linhas e {df_dadoscomerciais.shape[0]} Colunas

Nulos:
{df_dadoscomerciais.isnull().sum()}
""")
# Out:
# Tipo de dados:
# DatGeracaoConjuntoDados          object
# NumCNPJ                           int64
# SigAgente                        object
# NomAgente                        object
# NomTipoOutorga                   object
# DatReferenciaInformada           object
# CodMunicipioIBGE                  int64
# QtdUCAtiva                        int64
# QtdUCAtivaFat                     int64
# QtdFatura                         int64
# QtdFaturaSemLeitura               int64
# QtdFaturaSemLeituraImpAcesso      int64
# QtdFaturaSemLeituraEmergencia     int64
# QtdFaturaSemLeituraPlurimensa     int64
# QtdFaturaSemLeituraFatEstimad     int64
# QtdFaturaSemLeituraFimContrat     int64
# QtdFaturaSemLeituraAusenciaTm     int64
# QtdRefaturamento                  int64
# QtdFaturaAcerto                   int64
# QtdFaturaAcertoFatIncorreto       int64
# QtdFaturaAcertoFatIncorDevDob     int64
# QtdFaturaAcertoFatIncorDevSEC     int64
# QtdFaturaAcertoFatIncorDevSET     int64
# ...

# %%
# Corrigindo os tipos de dado.

pd.reset_option('display.max_rows')


string_cols = ['SigAgente', 'NomAgente', 'NomTipoOutorga']
float_cols = ['VlrRestAnte', 'VlrRestAtrasado', 'VlrRestPendente', 'VlrRestPendenteAtrasado','VlrPendentePgtRessarcDanoDefe',
              'VlrPagoRessarcDano', 'MdaTempoMedAtendimentoPosto', 'MdaTempoMedAtendPostoDiaFort', 'VlrTotCompSuspIndevida']
dt_cols = ['DatGeracaoConjuntoDados', 'DatReferenciaInformada', 'DthCarga']

df_dadoscomerciais[float_cols] = df_dadoscomerciais[float_cols].replace({",":"."}, regex=True)

df_dadoscomerciais[string_cols] = df_dadoscomerciais[string_cols].astype(str)
df_dadoscomerciais[float_cols] = df_dadoscomerciais[float_cols].astype(float)
df_dadoscomerciais[dt_cols] = df_dadoscomerciais[dt_cols].apply(pd.to_datetime)

# %%
# Análise inicial da base de dados do IBGE.
df_municipios.head()
# Out:
#    UF   Nome_UF  Região Geográfica Intermediária  \
# 0  11  Rondônia                             1102
# 1  11  Rondônia                             1102
# 2  11  Rondônia                             1101
# 3  11  Rondônia                             1102
# 4  11  Rondônia                             1101
#
#   Nome Região Geográfica Intermediária  Região Geográfica Imediata  \
# 0                            Ji-Paraná                      110005
# 1                            Ji-Paraná                      110005
# 2                          Porto Velho                      110002
# 3                            Ji-Paraná                      110004
# 4                          Porto Velho                      110002
#
#   Nome Região Geográfica Imediata  Mesorregião Geográfica   Nome_Mesorregião  \
# 0                          Cacoal                       2  Leste Rondoniense
# 1                          Cacoal                       2  Leste Rondoniense
# ...

# %%
municipios_cols = ['UF', 'Nome_UF', 'Município', 'Código Município Completo', 'Nome_Município']
df_municipios_filter = df_municipios[municipios_cols]

print(f"""Tipo de dados:
{df_municipios_filter.dtypes}

Colunas:
{df_municipios_filter.columns}

Formato:
{df_municipios_filter.shape[0]} Linhas e {df_municipios_filter.shape[0]} Colunas

Nulos:
{df_municipios_filter.isnull().sum()}

""")
# Out:
# Tipo de dados:
# UF                            int64
# Nome_UF                      object
# Município                     int64
# Código Município Completo     int64
# Nome_Município               object
# dtype: object
#
# Colunas:
# Index(['UF', 'Nome_UF', 'Município', 'Código Município Completo',
#        'Nome_Município'],
#       dtype='object')
#
# Formato:
# 5570 Linhas e 5570 Colunas
#
# Nulos:
# UF                           0
# Nome_UF                      0
# Município                    0
# Código Município Completo    0
# Nome_Município               0
# dtype: int64

# %%
# Corrigindo os tipos dos dados

municipios_str_cols = ['Nome_UF', 'Nome_Município']
df_municipios_filter[municipios_str_cols] = df_municipios_filter[municipios_str_cols].astype(str)
# Out:
# C:\Users\nielr\AppData\Local\Temp\ipykernel_24600\25622604.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_municipios_filter[municipios_str_cols] = df_municipios_filter[municipios_str_cols].astype(str)

# %%
#Realizando o cruzamento das tabelas para obter as informações dos municípios.

df_dadoscomerciais_merge = df_dadoscomerciais.merge(df_municipios_filter,
                                                    how = 'left',
                                                    left_on = 'CodMunicipioIBGE',
                                                    right_on ='Código Município Completo',
                                                    )

df_dadoscomerciais_merge
# Out:
#        DatGeracaoConjuntoDados         NumCNPJ SigAgente  \
# 0                   2024-08-05   1229747000189   Cergapa
# 1                   2024-08-05   1229747000189   Cergapa
# 2                   2024-08-05   1229747000189   Cergapa
# 3                   2024-08-05   1229747000189   Cergapa
# 4                   2024-08-05   1229747000189   Cergapa
# ...                        ...             ...       ...
# 110126              2024-08-05  98042963000152   Certhil
# 110127              2024-08-05  98042963000152   Certhil
# 110128              2024-08-05  98042963000152   Certhil
# 110129              2024-08-05  98042963000152   Certhil
# 110130              2024-08-05  98042963000152   Certhil
#
#                                                 NomAgente NomTipoOutorga  \
# 0                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# 1                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ      Permissão
# ...

# %%
# Aqui estamos realizando um filtro para manter somente as colunas relevantes para nossa análise.

df_dadoscomerciais_merge_final = df_dadoscomerciais_merge[['NumCNPJ',
                                                            'SigAgente',
                                                            'NomAgente',
                                                            'DatReferenciaInformada',
                                                            'CodMunicipioIBGE',
                                                            'UF',
                                                            'Nome_UF',
                                                            'Nome_Município',
                                                            ]]
df_dadoscomerciais_merge_final
# Out:
#                NumCNPJ SigAgente  \
# 0        1229747000189   Cergapa
# 1        1229747000189   Cergapa
# 2        1229747000189   Cergapa
# 3        1229747000189   Cergapa
# 4        1229747000189   Cergapa
# ...                ...       ...
# 110126  98042963000152   Certhil
# 110127  98042963000152   Certhil
# 110128  98042963000152   Certhil
# 110129  98042963000152   Certhil
# 110130  98042963000152   Certhil
#
#                                                 NomAgente  \
# 0                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ
# 1                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ
# 2                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ
# 3                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ
# 4                COOPERATIVA DE ELETRICIDADE DE GRÃO PARÁ
# ...                                                   ...
# 110126  COOPERATIVA DE DISTRIBUIÇÃO DE ENERGIA ENTRE R...
# 110127  COOPERATIVA DE DISTRIBUIÇÃO DE ENERGIA ENTRE R...
# ...

# %%
# Realizando uma agregação para por UF e Concessionária para uma sumarização.

df_concessionarias_por_uf = df_dadoscomerciais_merge_final.groupby(['Nome_UF', 'UF', 'SigAgente', 'NumCNPJ']).agg(UltimoRegistro=('DatReferenciaInformada', 'max')).reset_index()
df_concessionarias_por_uf.head()
# Out:
#    Nome_UF  UF              SigAgente         NumCNPJ UltimoRegistro
# 0     Acre  12            Energisa AC   4065033000170     2024-06-01
# 1  Alagoas  27          Equatorial AL  12272084000100     2024-06-01
# 2  Alagoas  27      Neoenergia Coelba  15139629000194     2024-06-01
# 3  Alagoas  27  Neoenergia Pernambuco  10835932000108     2024-06-01
# 4    Amapá  16         CEA Equatorial   5965546000109     2024-06-01

# %%
# Realizando uma transformação para validar a última data de atuação de cada concessionária em cada estado.
# Adicionando uma nova coluna que contém a contagem do número de concessionárias por estado.

df_concessionarias_por_uf["DataMax"] = df_concessionarias_por_uf.groupby("SigAgente")["UltimoRegistro"].transform("max")
df_concessionarias_por_uf = df_concessionarias_por_uf[
    df_concessionarias_por_uf["UltimoRegistro"] == df_concessionarias_por_uf["DataMax"]
]
df_concessionarias_por_uf["Quantidade_Concessionárias_UF"] = df_concessionarias_por_uf.groupby("Nome_UF")["SigAgente"].transform("count")

# %%
# Removendo a coluna redundante.

df_concessionarias_por_uf = df_concessionarias_por_uf.drop("DataMax", axis=1)
df_concessionarias_por_uf.head()
# Out:
#    Nome_UF  UF              SigAgente         NumCNPJ UltimoRegistro  \
# 0     Acre  12            Energisa AC   4065033000170     2024-06-01
# 1  Alagoas  27          Equatorial AL  12272084000100     2024-06-01
# 2  Alagoas  27      Neoenergia Coelba  15139629000194     2024-06-01
# 3  Alagoas  27  Neoenergia Pernambuco  10835932000108     2024-06-01
# 4    Amapá  16         CEA Equatorial   5965546000109     2024-06-01
#
#    Quantidade_Concessionárias_UF
# 0                              1
# 1                              3
# 2                              3
# 3                              3
# 4                              1

# %%
# Realizando uma agregação para por Município e Concessionária para uma sumarização.
df_concessionarias_por_municipio = df_dadoscomerciais_merge_final.groupby(
    ['Nome_Município', 'SigAgente', 'NumCNPJ']
).agg(
    UltimoRegistro=('DatReferenciaInformada', 'max')
).reset_index()

# %%
# Realizando uma transformação para validação sobre a última data de atuação da Concessionária em cada município.
df_concessionarias_por_municipio["DataMax"] = df_concessionarias_por_municipio.groupby("SigAgente")["UltimoRegistro"].transform("max")
df_concessionarias_por_municipio = df_concessionarias_por_municipio[
    df_concessionarias_por_municipio["UltimoRegistro"] == df_concessionarias_por_municipio["DataMax"]
]

df_concessionarias_por_municipio["Quantidade_Concessionárias_Município"] = df_concessionarias_por_municipio.groupby("Nome_Município")["SigAgente"].transform("count")

# %%
# Removendo a coluna redundante.
df_concessionarias_por_municipio = df_concessionarias_por_municipio.drop("DataMax", axis=1)
df_concessionarias_por_municipio.head()
# Out:
#         Nome_Município      SigAgente        NumCNPJ UltimoRegistro  \
# 0      Abadia de Goiás        Enel GO  1543032000104     2024-06-01
# 1  Abadia dos Dourados        Cemig-D  6981180000116     2024-06-01
# 2            Abadiânia        Enel GO  1543032000104     2024-06-01
# 3           Abaetetuba  Equatorial PA  4895728000180     2024-06-01
# 4               Abaeté        Cemig-D  6981180000116     2024-06-01
#
#    Quantidade_Concessionárias_Município
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.barplot(data=df_concessionarias_por_uf,
              x="Nome_UF",
              y="Quantidade_Concessionárias_UF",
              color="Darkblue",
              order = df_concessionarias_por_uf['Nome_UF'].value_counts().index

)
plt.title("Quantidade de Concessionárias por UF", fontsize = 16)
plt.xlabel("Estado")
plt.ylabel("Quantidade de Concessionárias")
plt.xticks(rotation=90);
plt.ylim(0,30)
# Out:
# (0.0, 30.0)

# %%
# Quantidade de Concessionárias por estado em forma de tabela.

sumarizacao_uf = (df_concessionarias_por_uf[["Nome_UF", "Quantidade_Concessionárias_UF"]]
        .drop_duplicates().
        sort_values(by="Quantidade_Concessionárias_UF", ascending=False)
        .reset_index(drop=True))
sumarizacao_uf
# Out:
#                 Nome_UF  Quantidade_Concessionárias_UF
# 0        Santa Catarina                             27
# 1     Rio Grande do Sul                             20
# 2             São Paulo                             19
# 3          Minas Gerais                              9
# 4                Paraná                              7
# 5        Rio de Janeiro                              6
# 6               Sergipe                              3
# 7               Alagoas                              3
# 8    Mato Grosso do Sul                              2
# 9            Pernambuco                              2
# 10              Paraíba                              2
# 11            Tocantins                              2
# 12                Goiás                              2
# 13       Espírito Santo                              2
# 14                Bahia                              2
# 15          Mato Grosso                              1
# ...

# %%
# Dados estatísticos sobre as informações obtidas.
sumarizacao_uf.describe()
# Out:
#        Quantidade_Concessionárias_UF
# count                      27.000000
# mean                        4.444444
# std                         6.738713
# min                         1.000000
# 25%                         1.000000
# 50%                         2.000000
# 75%                         3.000000
# max                        27.000000

# %%
df_concessionarias_por_uf.to_csv('../../data/processed/ANEEL/df_concessionarias_por_uf.csv')
df_concessionarias_por_municipio.to_csv('../../data/processed/ANEEL/df_concessionarias_por_municipio.csv')

# %% [markdown]
# ## 2. **ONS**

# %%
df_capacidade_geracao = pd.read_parquet('../../data/external/ONS/capacidade_geracao/capacidade_geracao.parquet')

# %% [markdown]
# ## Preprocessamento

# %% [markdown]
# ### Tipagem e características da tabela

# %%
df_capacidade_geracao.head()
# Out:
#   id_subsistema nom_subsistema id_estado nom_estado nom_modalidadeoperacao  \
# 0            NE       NORDESTE        AL    ALAGOAS                 TIPO I
# 1            NE       NORDESTE        AL    ALAGOAS                 TIPO I
# 2            NE       NORDESTE        AL    ALAGOAS                 TIPO I
# 3            NE       NORDESTE        AL    ALAGOAS                 TIPO I
# 4            NE       NORDESTE        AL    ALAGOAS                 TIPO I
#
#   nom_agenteproprietario  nom_tipousina nom_usina                    ceg  \
# 0                  CHESF  HIDROELÉTRICA     XINGÓ  UHE.PH.SE.027053-9.01
# 1                  CHESF  HIDROELÉTRICA     XINGÓ  UHE.PH.SE.027053-9.01
# 2                  CHESF  HIDROELÉTRICA     XINGÓ  UHE.PH.SE.027053-9.01
# 3                  CHESF  HIDROELÉTRICA     XINGÓ  UHE.PH.SE.027053-9.01
# 4                  CHESF  HIDROELÉTRICA     XINGÓ  UHE.PH.SE.027053-9.01
#
#                          nom_unidadegeradora cod_equipamento  \
# ...

# %%
print(f"""Tipo de dados:
{df_capacidade_geracao.dtypes}

Colunas:
{df_capacidade_geracao.columns}

Formato:
{df_capacidade_geracao.shape}

Nulos:
{df_capacidade_geracao.isnull().sum()}
""")
# Out:
# Tipo de dados:
# id_subsistema              object
# nom_subsistema             object
# id_estado                  object
# nom_estado                 object
# nom_modalidadeoperacao     object
# nom_agenteproprietario     object
# nom_tipousina              object
# nom_usina                  object
# ceg                        object
# nom_unidadegeradora        object
# cod_equipamento            object
# num_unidadegeradora        object
# nom_combustivel            object
# dat_entradateste           object
# dat_entradaoperacao        object
# dat_desativacao            object
# val_potenciaefetiva       float64
# dtype: object
#
# Colunas:
# Index(['id_subsistema', 'nom_subsistema', 'id_estado', 'nom_estado',
#        'nom_modalidadeoperacao', 'nom_agenteproprietario', 'nom_tipousina',
#        'nom_usina', 'ceg', 'nom_unidadegeradora', 'cod_equipamento',
#        'num_unidadegeradora', 'nom_combustivel', 'dat_entradateste',
# ...

# %%
# Corrigindo tipo de dado segundo documentação
string_cols = [
    'id_subsistema', 'nom_subsistema', 'id_estado', 'nom_estado', 'nom_modalidadeoperacao', 'nom_agenteproprietario', 'nom_tipousina',
    'nom_usina', 'ceg', 'nom_unidadegeradora', 'cod_equipamento', 'num_unidadegeradora', 'nom_combustivel',
]

datetime_cols = ['dat_entradateste', 'dat_entradaoperacao', 'dat_desativacao']

df_capacidade_geracao[string_cols] = df_capacidade_geracao[string_cols].astype(str)
df_capacidade_geracao[datetime_cols] = df_capacidade_geracao[datetime_cols].apply(pd.to_datetime)

# %%
# Embora não tenham dados nulos, dada existência de dados vazios nas datas inexistentes,
# registros nulos (NaT) são gerados
df_capacidade_geracao[datetime_cols].isnull().sum()
# Out:
# dat_entradateste         12
# dat_entradaoperacao       0
# dat_desativacao        4106
# dtype: int64

# %% [markdown]
# ### Usinas com fontes renováveis ativas

# %%
# Filtrando unidades geradores ativas e comissionadas (condições de operação verificadas)
df_capacidade_geracao_ativa = df_capacidade_geracao[
    df_capacidade_geracao['dat_desativacao'].isnull()
    & df_capacidade_geracao['dat_entradateste'].notnull()
]

# Filtrando energias renováveis
df_capacidade_geracao_ativa = df_capacidade_geracao_ativa[
    df_capacidade_geracao_ativa['nom_combustivel'].isin(
        ['HIDRÁULICA', 'EÓLICA', 'FOTOVOLTAICA', 'NUCLEAR']
    )
]

print(df_capacidade_geracao.shape, df_capacidade_geracao_ativa.shape)
# Out:
# (5064, 17) (3619, 17)

# %% [markdown]
# ### Geração em MWh

# %%
"""
Considerando que:
    Todas as usinas operam com 90% de sua capacidade;
    Usinas fotovoltaicas operam apenas 12h/dia (Apenas quando há sol).
"""

df_capacidade_geracao_ativa['potencia_mwh'] = np.where(
    df_capacidade_geracao_ativa['nom_combustivel'] == 'FOTOVOLTAICA',
    df_capacidade_geracao_ativa['val_potenciaefetiva'] * 12 * .9,
    df_capacidade_geracao_ativa['val_potenciaefetiva'] * 24 * .9
)

# %% [markdown]
# ## Agregando informações por usina

# %%
df_capacidade_usina = df_capacidade_geracao_ativa.groupby(
    [
        'ceg', 'nom_combustivel', 'nom_agenteproprietario',
        'nom_estado', 'id_estado', 'nom_subsistema', 'id_subsistema'
    ], as_index=False
).agg(
    unidades_geradoras = ('num_unidadegeradora', 'count'),
    potencia_nominal_mw = ('val_potenciaefetiva', 'sum'),
    potencia_mwh = ('potencia_mwh', 'sum')
)

# %%
df_capacidade_tipo_uf = df_capacidade_usina.groupby(
    ['id_estado', 'nom_estado', 'nom_combustivel'], as_index=False
)[['unidades_geradoras', 'potencia_nominal_mw', 'potencia_mwh']].sum()

df_capacidade_tipo_subsist = df_capacidade_usina.groupby(
    ['id_subsistema', 'nom_subsistema', 'nom_combustivel'], as_index=False
)[['unidades_geradoras', 'potencia_nominal_mw', 'potencia_mwh']].sum()

df_capacidade_tipo_agente = df_capacidade_usina.groupby(
    ['nom_agenteproprietario', 'nom_combustivel'], as_index=False
)[['unidades_geradoras', 'potencia_nominal_mw', 'potencia_mwh']].sum()

# %% [markdown]
# ## Visualização

# %% [markdown]
# ### Capacidade de geração por usina, Estado e subsistema

# %%
plt.figure(figsize=(12, 6))
plt.title('Capacidade de Geração por Tipo de Usina e Estado')
sns.barplot(
    data=df_capacidade_tipo_uf,
    x='nom_estado', y='potencia_mwh', hue='nom_combustivel',
    errorbar=None,

)
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(12, 6))
plt.title('Capacidade de Geração por Tipo de Usina e Subsistema')
sns.barplot(
    data=df_capacidade_tipo_subsist,
    x='nom_subsistema', y='potencia_mwh', hue='nom_combustivel',
    errorbar=None,
)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Capacidade de geração por concessionária

# %%
top5_agentes = df_capacidade_tipo_agente.sort_values(
    'potencia_mwh', ascending=False
).groupby('nom_combustivel').head(5)

# %%
plt.figure(figsize=(12, 6))
plt.title('TOP 5 Agentes Proprietário por Tipo de Usina')
sns.barplot(
    data=top5_agentes,
    x='nom_agenteproprietario', y='potencia_mwh', hue='nom_combustivel',
    errorbar=None,
)
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(12, 6))
plt.title('TOP 5 Agentes Proprietário por Tipo de Usina - Sem Hidraulica')
sns.barplot(
    data=top5_agentes[top5_agentes['nom_combustivel'] != 'HIDRÁULICA'],
    x='nom_agenteproprietario', y='potencia_mwh', hue='nom_combustivel',
    errorbar=None,
)
plt.xticks(rotation=90)
plt.show()

# %%
# Quantidade de agentes por tipo
df_capacidade_tipo_agente.groupby('nom_combustivel', as_index=False)['nom_agenteproprietario'].count()
# Out:
#   nom_combustivel  nom_agenteproprietario
# 0          EÓLICA                     887
# 1    FOTOVOLTAICA                     239
# 2      HIDRÁULICA                     103
# 3         NUCLEAR                       1

# %% [markdown]
# ## Salvando arquivos

# %%
df_capacidade_usina.to_parquet('../../data/processed/ONS/capacidade_usina.parquet')
df_capacidade_tipo_uf.to_parquet('../../data/processed/ONS/capacidade_tipo_uf.parquet')
df_capacidade_tipo_subsist.to_parquet('../../data/processed/ONS/capacidade_tipo_subsist.parquet')
df_capacidade_tipo_agente.to_parquet('../../data/processed/ONS/capacidade_tipo_agente.parquet')

# %% [markdown]
# ## 3. **EPE**

# %%
import plotly.express as px
from datetime import datetime

from IPython.display import display

# %%
# Definição do caminho do arquivo
file_path = '../../data/external/EPE/consumo_mensal/dados_abertos_consumo_mensal.xlsx'

# Obter todos os nomes das abas
xls = pd.ExcelFile(file_path)
sheet_names = xls.sheet_names  # Lista com os nomes de todas as abas

# Carregar todas as sheets do Excel em um dicionário de DataFrames
data = {sheet: pd.read_excel(file_path, sheet_name=sheet) for sheet in sheet_names}
sheet_names
# Out:
# ['CONSUMO E NUMCONS SAM',
#  'CONSUMO E NUMCONS SAM UF',
#  'SETOR INDUSTRIAL POR RG',
#  'ANALISE CONS NUMCONS SAM',
#  'ANALISE CONS NUMCONS SAM UF',
#  'ANALISE SETOR IND POR RG']

# %%
# Removendo as últimas 3 sheets
sheets_to_remove = ['ANALISE CONS NUMCONS SAM', 'ANALISE CONS NUMCONS SAM UF', 'ANALISE SETOR IND POR RG']
for sheet in sheets_to_remove:
    if sheet in data:
        del data[sheet]

# Verificando as sheets restantesa
print("Sheets restantes após remoção:")
print(data.keys())
# Out:
# Sheets restantes após remoção:
# dict_keys(['CONSUMO E NUMCONS SAM', 'CONSUMO E NUMCONS SAM UF', 'SETOR INDUSTRIAL POR RG'])

# %%
# Verificando as primeiras linhas de cada sheet
for sheet in data:
    print(f"\nPrimeiras linhas da aba: {sheet}")
    display(data[sheet].head())
# Out:
# Primeiras linhas da aba: CONSUMO E NUMCONS SAM
#        Data  DataExcel        Regiao                   Sistema      Classe  \
# 0  20240601 2024-06-01  Centro-Oeste  SUDESTE / CENTRO - OESTE   Comercial
# 1  20240601 2024-06-01  Centro-Oeste  SUDESTE / CENTRO - OESTE   Comercial
# 2  20240601 2024-06-01  Centro-Oeste  SUDESTE / CENTRO - OESTE  Industrial
# 3  20240601 2024-06-01  Centro-Oeste  SUDESTE / CENTRO - OESTE  Industrial
# 4  20240601 2024-06-01  Centro-Oeste  SUDESTE / CENTRO - OESTE      Outros
#
#   TipoConsumidor     Consumo  Consumidores
# 0         Cativo  448252.309      503876.0
# 1          Livre  200313.573        2075.0
# 2         Cativo   81441.302       31757.0
# 3          Livre  884213.886         899.0
# 4         Cativo  359051.301       63248.0
# Primeiras linhas da aba: CONSUMO E NUMCONS SAM UF
#        Data  DataExcel  UF Regiao            Sistema       Classe  \
# 0  20240501 2024-05-01  AC  Norte  SISTEMAS ISOLADOS    Comercial
# ...

# %%
# Exibindo os tipos de dados e estatísticas descritivas para cada aba
for sheet in data:
    print(f"\nTipos de dados da aba: {sheet}")
    print(display(data[sheet].dtypes))

    print(f"\nEstatísticas descritivas da aba: {sheet}")
    print(display(data[sheet].describe(include='all')))
# Out:
# Tipos de dados da aba: CONSUMO E NUMCONS SAM
# Data                       int64
# DataExcel         datetime64[ns]
# Regiao                    object
# Sistema                   object
# Classe                    object
# TipoConsumidor            object
# Consumo                  float64
# Consumidores             float64
# dtype: object
# None
#
# Estatísticas descritivas da aba: CONSUMO E NUMCONS SAM
#                 Data                      DataExcel    Regiao  \
# count   1.666100e+04                          16661     16661
# unique           NaN                            NaN         5
# top              NaN                            NaN  Nordeste
# freq             NaN                            NaN      4924
# mean    2.014491e+07  2014-11-17 08:01:19.515034880       NaN
# min     2.004010e+07            2004-01-01 00:00:00       NaN
# 25%     2.010020e+07            2010-02-01 00:00:00       NaN
# 50%     2.015040e+07            2015-04-01 00:00:00       NaN
# ...

# %%
# Tratamento de valores faltantes e inconsistentes
for sheet in data:
    print(f"\nValores faltantes na aba: {sheet}")

    # Contagem total de valores faltantes
    missing_total = data[sheet].isnull().sum().sum()
    print(f"Total de valores faltantes: {missing_total}")

    # Exibe também a contagem de valores faltantes por coluna
    missing_count = data[sheet].isnull().sum()
    print("Contagem de valores faltantes por coluna:")
    print(missing_count)

    # Após verificar, preenche valores faltantes (estratégia simples)
    for column in data[sheet].columns:
        if data[sheet][column].dtype == 'object':
            # Preencher valores categóricos com o valor mais comum (moda)
            data[sheet][column].fillna(data[sheet][column].mode()[0], inplace=True)
        else:
            # Preencher valores numéricos com a média
            data[sheet][column].fillna(data[sheet][column].mean(), inplace=True)
# Out:
# Valores faltantes na aba: CONSUMO E NUMCONS SAM
# Total de valores faltantes: 0
# Contagem de valores faltantes por coluna:
# Data              0
# DataExcel         0
# Regiao            0
# Sistema           0
# Classe            0
# TipoConsumidor    0
# Consumo           0
# Consumidores      0
# dtype: int64
# Valores faltantes na aba: CONSUMO E NUMCONS SAM UF
# Total de valores faltantes: 0
# Contagem de valores faltantes por coluna:
# Data              0
# DataExcel         0
# UF                0
# Regiao            0
# Sistema           0
# Classe            0
# TipoConsumidor    0
# Consumo           0
# Consumidores      0
# dtype: int64
#
# Valores faltantes na aba: SETOR INDUSTRIAL POR RG
# Total de valores faltantes: 0
# Contagem de valores faltantes por coluna:
# Data               0
# DataExcel          0
# SetorIndustrial    0
# Regiao             0
# Consumo            0
# dtype: int64
# ...

# %%
# Distribuição do consumo por região e classe
plt.figure(figsize=(10,6))
sns.barplot(x='Regiao', y='Consumo', hue='Classe', data=data['CONSUMO E NUMCONS SAM'])
plt.title('Consumo por Região e Classe - CONSUMO E NUMCONS SAM')
plt.ylabel('Consumo (MWh)')
plt.show()

# %% [markdown]
# ### *Distribuição de Consumo por Região e Classe*:
#
# - **Análise**: Ao visualizar o gráfico de barras do consumo por **região** e **classe**, é possível identificar quais regiões possuem os maiores consumidores de energia elétrica e se existe uma classe que consome mais em cada região.
#
# **Exemplo de Insight**:
#
# - **Regiões metropolitanas** podem apresentar um consumo elevado em classes **residenciais** e **comerciais**, enquanto regiões mais industriais podem ter um consumo maior na **classe industrial**.
# - Se observarmos que a classe **residencial** tem o maior consumo em várias regiões, isso pode sugerir um crescimento populacional elevado ou uma maior dependência de eletricidade nas atividades diárias.
#
# **Ação**: As concessionárias podem priorizar políticas de eficiência energética nessas regiões para mitigar o consumo em horários de pico.

# %%
# Comparação de consumo por Unidade da Federação (UF)
plt.figure(figsize=(14,7))
sns.barplot(x='UF', y='Consumo', data=data['CONSUMO E NUMCONS SAM UF'])
plt.title('Consumo por Unidade da Federação (UF) - CONSUMO E NUMCONS SAM UF')
plt.ylabel('Consumo (MWh)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### *Consumo por Unidade da Federação (UF)*:
#
# - **Análise**: Gráficos que comparam o consumo entre diferentes **Unidades da Federação (UF)** podem revelar quais estados consomem mais energia, e podem estar relacionados com características locais, como o desenvolvimento industrial ou densidade populacional.
#
# **Exemplo de Insight**:
#
# - Se o estado de **São Paulo** é responsável pelo maior consumo, isso pode ser reflexo do grande número de indústrias e da população elevada.
# - Estados com menor consumo de energia podem indicar infraestrutura elétrica menos desenvolvida ou menor presença de atividades industriais.
#
# **Ação**: Investimentos podem ser direcionados a estados com menor consumo para melhorar a infraestrutura elétrica, enquanto estados de alto consumo podem adotar políticas de incentivo à eficiência energética.

# %%
# Consumo dos setores industriais por região
if 'SETOR INDUSTRIAL POR RG' in data:
    plt.figure(figsize=(14,6))
    sns.barplot(x='Regiao', y='Consumo', hue='SetorIndustrial', data=data['SETOR INDUSTRIAL POR RG'])
    plt.title('Consumo por Setor Industrial e Região - SETOR INDUSTRIAL POR RG')
    plt.ylabel('Consumo (MWh)')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### *Consumo por Setor Industrial e Região*:
#
# - **Análise**: Ao observar o consumo de energia elétrica dividido por **setores industriais** e **regiões**, é possível identificar quais setores da economia estão demandando mais energia em diferentes partes do país.
#
# **Exemplo de Insight**:
#
# - Se o setor **metalúrgico** ou **químico** apresenta um consumo elevado em uma região específica, isso pode sugerir a presença de grandes polos industriais nessas áreas.
# - A **indústria de alimentos** pode ter maior consumo em regiões agrícolas ou produtoras, enquanto setores como o **têxtil** podem estar concentrados em áreas com mão de obra intensiva.
#
# **Ação**: A alocação de energia e planejamento de infraestrutura pode ser direcionado para apoiar esses setores e minimizar o risco de sobrecarga.

# %%
# Análise Temporal (se houver colunas de data)
for sheet in data:
    if 'Data' in data[sheet].columns and 'Consumo' in data[sheet].columns:
        # Garantindo que a coluna 'Data' seja string antes da conversão
        data[sheet]['Data'] = data[sheet]['Data'].astype(str)

        # Convertendo a coluna de data que está no formato AAAAMMDD para datetime
        data[sheet]['Data'] = pd.to_datetime(data[sheet]['Data'], format='%Y%m%d', errors='coerce')

        # Removendo valores onde a conversão falhou
        data[sheet].dropna(subset=['Data'], inplace=True)

        # Verificar se a coluna 'Consumo' tem valores válidos
        if data[sheet]['Consumo'].isnull().all():
            print(f"Aba {sheet}: Nenhum valor válido na coluna 'Consumo'. Pulando análise temporal.")
            continue

        # Agrupando por mês e somando os valores de consumo
        consumo_mensal = data[sheet].groupby(data[sheet]['Data'].dt.to_period('M'))['Consumo'].sum()

        # Verificando se o agrupamento gerou resultados
        if consumo_mensal.empty:
            print(f"Aba {sheet}: Nenhum dado disponível após o agrupamento. Pulando plotagem.")
            continue

        # Plotando o consumo mensal
        plt.figure(figsize=(10,6))
        consumo_mensal.plot()
        plt.title(f'Consumo Mensal ao Longo do Tempo - {sheet}')
        plt.ylabel('Consumo (MWh)')
        plt.xlabel('Mês')
        plt.show()

# %% [markdown]
# ### *Análise Temporal*:
#
# - **Análise**: Analisando o consumo ao longo do tempo, você pode identificar **tendências sazonais** ou **picos de consumo** relacionados a épocas do ano.
#
# **Exemplo de Insight**:
#
# - Um aumento no consumo durante o verão pode estar relacionado ao uso mais frequente de **ar-condicionado** ou **ventiladores**, enquanto picos no inverno podem refletir o uso de **aquecedores elétricos**.
# - O comportamento do consumo ao longo do tempo pode sugerir a necessidade de programas de gerenciamento de demanda para evitar sobrecarga nas redes elétricas em certos períodos.

# %%
# Verificando outliers com boxplot
plt.figure(figsize=(10,6))
sns.boxplot(data['CONSUMO E NUMCONS SAM']['Consumo'])
plt.title("Distribuição de Outliers no Consumo")
plt.show()

# Se necessário, remover outliers
Q1 = data['CONSUMO E NUMCONS SAM']['Consumo'].quantile(0.25)
Q3 = data['CONSUMO E NUMCONS SAM']['Consumo'].quantile(0.75)
IQR = Q3 - Q1
outliers_removed = data['CONSUMO E NUMCONS SAM'][
    ~((data['CONSUMO E NUMCONS SAM']['Consumo'] < (Q1 - 1.5 * IQR)) |
      (data['CONSUMO E NUMCONS SAM']['Consumo'] > (Q3 + 1.5 * IQR)))
]

# %% [markdown]
# # **Modelos**
#
#     Descrição metodológica para a criação, refinamento e validação dos modelos propostos.

# %% [markdown]
# ## Proposta
#
# A modelagem a seguir diz respeito a projeção do consumo mensal residencial (majoritariamente urbano) de energia elétrica no Brasil.
#
# A fim de simplificar o problema, serão considerados apenas sistemas cativos, vinculados a apenas uma distribuidora de energia, com cobranças mensais, e, a maior granularidade estudada será a Região Geográfica.
#
# Além disso, a proposta atual é que as projeções sejam no horizonte de 6 meses.
#
# ## Validação cruzada
#
# A fim de garantir estabilidade e confiabilidade das projeções a longo prazo, foi realizado um processo de validação cruzada em intervalos de 6 meses de Junho/2018 a Dezembro/2023, conforme elucida a figura abaixo
#
# ![image.png](attachment:image.png)
#
# Figura 2 - Validação Cruzada de Séries Temporais
#
#
# Meses de corte|
# -|
# 2018-06-01|
# 2018-12-01|
# 2019-06-01|
# 2019-12-01|
# 2020-06-01|
# 2020-12-01|
# 2021-06-01|
# 2021-12-01|
# 2022-06-01|
# 2022-12-01|
# 2023-06-01|
# 2023-12-01|
#
# Tabela - Meses de corte para valicação cruzada, no formato Ano-Mes-01

# %% [markdown]
# ## Ambiente

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from prophet import Prophet
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# ## Dados

# %%
df_consumo_mensal = pd.read_excel(
    '../../data/external/EPE/consumo_mensal/dados_abertos_consumo_mensal.xlsx',
    sheet_name="CONSUMO E NUMCONS SAM"
)

# %% [markdown]
# ## Pré-processamento

# %%
df_consumo_residencial = df_consumo_mensal[
    (df_consumo_mensal['Classe'] == 'Residencial')
    & (df_consumo_mensal['TipoConsumidor'] == 'Cativo')
    & (df_consumo_mensal['Sistema'] != 'SISTEMAS ISOLADOS')
].copy()

df_consumo_residencial['Data'] = df_consumo_residencial['DataExcel'].copy()
df_consumo_residencial['ConsumoConsumidores'] = df_consumo_residencial['Consumo'] / df_consumo_residencial['Consumidores']
df_consumo_residencial = df_consumo_residencial[['Data', 'Regiao', 'Sistema', 'Consumo', 'Consumidores', 'ConsumoConsumidores']]

# %%
# Separando regiões customizadas
df_consumo_residencial['RegiaoCustom'] = np.where(
    df_consumo_residencial['Sistema'] == "NORTE INTERLIGADO",
    df_consumo_residencial['Regiao'] + "-Interligado",
    df_consumo_residencial['Regiao']
)

regioes = df_consumo_residencial['RegiaoCustom'].unique()
regioes
# Out:
# array(['Centro-Oeste', 'Nordeste', 'Nordeste-Interligado',
#        'Norte-Interligado', 'Norte', 'Sudeste', 'Sul'], dtype=object)

# %% [markdown]
# ## Criação de Regiões Customizadas
# Devido à características distintas de diferentes sistemas, conforme indicam as Figuras *[x]* e *[y]* a criação de regiões customizadas se fez necessária, de forma a separar séries temporais com diferentes amplitudes dentro de uma mesma região. Esse comportamento distante é mais perceptível nas regiões norte e nordeste devido ao sistema "Interligado do Norte", que conecta as Regiões Norte e Nordeste. A relação de regiões customizadas encontra-se na Tabela *[x]*.
#
#
# ![image-3.png](attachment:image-3.png)
#
# Figura *[x]* - Consumo residencial mensal no Nordeste
#
#
# ![image.png](attachment:image.png)
#
# Figura *[y]* - Consumo residencial mensal no Norte
#
#
# Região|Sistema|Região Customizada
# -|-|-
# Nordeste|Nordeste|Nordeste
# Nordeste|Norte Interligado|Nordeste-Interligado
# Norte|Norte Interligado|Norte-Interligado
# Centro-Oeste|Sudeste / Centro-Oeste|Centro-Oeste
# Norte|Sudeste / Centro-Oeste|Norte
# Sudeste|Sudeste / Centro-Oeste|Sudeste
# Sul|Sul|Sul
#
#
# Tabela *[x]* - Relação entre regiões, sistemas e regiões customizadas

# %%
# NOTE: Ano-Mes 2015-01 selecionado com base na estabilidade do consumo e consumo por consumores
df_consumo_residencial = df_consumo_residencial[
    (df_consumo_residencial['Data'] >= '2015-01-01')
]

dict_consumo_regiao = {}
for regiao in regioes:
    dict_consumo_regiao[regiao] = df_consumo_residencial[
        (df_consumo_residencial['RegiaoCustom'] == regiao)
    ].copy()

# %%
# # Séries temporais de consumo residencial por região
# for regiao in df_consumo_residencial['Regiao'].unique():
#     sns.scatterplot(
#         data=df_consumo_residencial[df_consumo_residencial['Regiao'] == regiao],
#         x='Data', y='Consumo', hue='Sistema'
#     )
#     plt.ylabel('Consumo (MWh)')
#     plt.xlabel('Mês-Ano')
#     plt.title(f"Consumo Residencial por Mês - {regiao}")
#     plt.show()

# %% [markdown]
# ## Séries temporais de consumo residencial por região customizada

# %%
for regiao in regioes:
    plt.plot(
        dict_consumo_regiao[regiao]['Data'],
        dict_consumo_regiao[regiao]['Consumo'],
   )

    plt.title(f"Consumo Residencial - {regiao}")
    plt.show()

# %% [markdown]
# ## Criação do modelo

# %%
def feature_covid(no_am_series: pd.Series):
    """
    Gera feature indicando período no qual ocorreu a pandemia da covid-19.
    """
    return no_am_series.between('2020-01-01', '2020-12-31').astype(int)

# %%
def gera_projecao_6m(
    prophet_model: Prophet,
    df_serie_temporal: pd.DataFrame,
    mes_limite: int,
    considera_covid: bool = False,
) -> pd.DataFrame:
    """
    Gera próximos 6 meses de consumo de energia elétrica residencial.

    Parâmetros
    ----------
    prophet_model : Modelo Prophet instanciado
    df_serie_temporal : DataFrame com dados a projetar
    mes_limite : Mês limite para treino do modelo, no formato 'yyyy-MM-01'
    """

    df_treino = df_serie_temporal[df_serie_temporal["ds"] <= mes_limite].copy()
    df_treino = df_treino[["ds", "y"]]

    if considera_covid:
        df_treino["COVID"] = feature_covid(df_treino["ds"])
        prophet_model.add_regressor("COVID", mode="additive")

    prophet_model.fit(df_treino)

    # Projetando N meses a frente
    future = prophet_model.make_future_dataframe(periods=6, freq="MS", include_history=False)

    if considera_covid:
        future["COVID"] = feature_covid(future["ds"])

    forecast = prophet_model.predict(future)
    forecast = forecast[["ds", "yhat"]]

    # Guardando referência do mês de projeção
    forecast["MES_REF"] = mes_limite
    forecast["MES_PROJECAO"] = forecast.groupby("MES_REF").cumcount() + 1

    return forecast

# %%
def formata_dataframe(
        df: pd.DataFrame,
        ds_col: str = "Data",
        y_col: str = "Consumo"
    ) -> pd.DataFrame:
    """
    Formata DataFrame para modelagem com Prophet.
    """

    df = df.copy()
    df = df.rename(columns={ds_col: "ds", y_col: "y"})
    df = df.sort_values("ds")

    return df[['ds', 'y']]
# Out:
# Meses para validação cruzada: ['2018-06-01', '2018-12-01', '2019-06-01', '2019-12-01', '2020-06-01', '2020-12-01', '2021-06-01', '2021-12-01', '2022-06-01', '2022-12-01', '2023-06-01', '2023-12-01']

# %% [markdown]
# ## Backtest com validação cruzada para avaliar performance do modelo

# %%
# Definição de meses para validação cruzada
meses_limite = [f"{ano}-{mes:02}-01" for ano in range(2018, 2024+1) for mes in [6,12]]
meses_limite = meses_limite[:-2]

print("Meses para validação cruzada:", meses_limite)

# %%
model_kwargs = {
    "growth": "linear",
    "seasonality_mode": "additive",
    "yearly_seasonality": True,
    "considera_covid": False,
}

def propeht_backtest(
    df_serie: pd.DataFrame,
    meses_limite: list,
    ds_col: str = "Data",
    y_col: str = "Consumo",
    model_kwargs: dict = {},
) -> pd.DataFrame:
    
    df_serie = formata_dataframe(df_serie, ds_col, y_col)

    df_projecao = pd.DataFrame()
    for mes in meses_limite:

        modelo_consumo = Prophet(
            growth=model_kwargs["growth"],
            seasonality_mode=model_kwargs["seasonality_mode"],
            yearly_seasonality=model_kwargs["yearly_seasonality"],
        )

        _df_projecao = gera_projecao_6m(
            modelo_consumo,
            df_serie,
            mes_limite=mes,
            considera_covid=model_kwargs["considera_covid"],
        )

        df_projecao = pd.concat([df_projecao, _df_projecao])
    
    df_results = df_serie.merge(df_projecao, on='ds')

    return df_results


def mape_wmape(y_true, y_pred):
    """
    Calcula WMAPE e MAPE de determinada projeção.
    """
    erro_abs_pct = np.abs(y_true - y_pred) / y_true
    wmape = sum(erro_abs_pct) / sum(y_true)
    mape = np.mean(erro_abs_pct)
    return mape, wmape

# %%
# NOTE: Caso ocorra o erro com "stanbackend", instale o prophet utilizando a linha de comando `conda install prophet`.
dict_backtests = {}
for regiao in regioes:
    dict_backtests[regiao] = propeht_backtest(
        dict_consumo_regiao[regiao],
        meses_limite,
        ds_col="Data",
        y_col="Consumo",
        model_kwargs=model_kwargs
    )

    dict_backtests[regiao]["RegiaoCustom"] = regiao
# Out:
# 19:32:40 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:40 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:41 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:41 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:41 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:41 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:42 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:42 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:43 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:44 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:32:44 - cmdstanpy - INFO - Chain [1] done processing
# 19:32:44 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %% [markdown]
# ### Histórico de consumo e projeções de validação cruzada

# %%
for regiao in regioes:

    plt.plot(
        dict_consumo_regiao[regiao]['Data'],
        dict_consumo_regiao[regiao]['Consumo'],
        label='Real'
    )

    plt.plot(
        dict_backtests[regiao]['ds'],
        dict_backtests[regiao]['yhat'],
        label='Projeção'
    )

    plt.ylabel('Consumo (MWh)')
    plt.xlabel('Mês-Ano')
    plt.title(f"Backtest para região {regiao}")
    plt.show()

    from scipy import stats
    r2 = stats.pearsonr(dict_backtests[regiao]['y'], dict_backtests[regiao]['yhat'])[0]**2

    linear = sns.regplot(dict_backtests[regiao], x='y', y='yhat')
    linear.set_title(f"Backtest para região {regiao} - R²: {r2:.2f}")
    plt.xlabel('Real')
    plt.ylabel('Projeção')
    plt.show()

# %%
df_avaliacao = pd.DataFrame()
for df in dict_backtests.values():
    df_avaliacao = pd.concat([df_avaliacao, df])

# %% [markdown]
# ### Resultados Gerais

# %%
# Resultados gerais
r2 = stats.pearsonr(df_avaliacao['y'], df_avaliacao['yhat'])[0]**2
mape, wmape = mape_wmape(df_avaliacao['y'], df_avaliacao['yhat'])
rmse = root_mean_squared_error(df_avaliacao['y'], df_avaliacao['yhat'])
rmse_relativo = rmse / df_avaliacao['y'].mean()

print(f"R²: {r2:.4f}\nMAPE: {mape*100:.2f}\nWMAPE: {wmape*100:.6f}\nRMSE: {rmse:.2f}\nRMSE relativo: {rmse_relativo:.2f}")
# Out:
# R²: 0.9952
# MAPE: 4.16
# WMAPE: 0.000002
# RMSE: 133019.49
# RMSE relativo: 0.07

# %% [markdown]
# ### Resultados Discredizados

# %%
# Resultados por região
dict_results = {
    "REGIAO": [],
    "R2": [],
    "MAPE": [],
    "WMAPE": [],
    "RMSE": [],
    "RMSE_RELATIVO": [],
}

for regiao in regioes:
    _df = df_avaliacao[df_avaliacao['RegiaoCustom'] == regiao]

    r2 = stats.pearsonr(_df['y'], _df['yhat'])[0]**2
    mape, wmape = mape_wmape(_df['y'], _df['yhat'])
    rmse = root_mean_squared_error(_df['y'], _df['yhat'])
    rmse_relativo = rmse / _df['y'].mean()

    dict_results["REGIAO"].append(regiao)
    dict_results["R2"].append(r2)
    dict_results["MAPE"].append(mape*100)
    dict_results["WMAPE"].append(wmape*100)
    dict_results["RMSE"].append(rmse)
    dict_results["RMSE_RELATIVO"].append(rmse_relativo)

# %%
pd.DataFrame(dict_results)
# Out:
#                  REGIAO        R2      MAPE         WMAPE           RMSE  \
# 0          Centro-Oeste  0.714811  4.175497  3.626769e-06   75287.120588
# 1              Nordeste  0.808587  3.148837  1.363189e-06   92907.573694
# 2  Nordeste-Interligado  0.925326  3.736450  1.147635e-05   15572.526849
# 3     Norte-Interligado  0.830946  5.147990  8.173436e-06   44049.680459
# 4                 Norte  0.818323  5.290304  3.341137e-05   11039.150531
# 5               Sudeste  0.632369  3.929849  6.586459e-07  309408.299058
# 6                   Sul  0.860381  3.712857  1.795659e-06  107336.356800
#
#    RMSE_RELATIVO
# 0       0.065393
# 1       0.040221
# 2       0.047830
# 3       0.069937
# 4       0.069719
# 5       0.051857
# 6       0.051911

# %%
# Resultado por mês de backtest (maior mês de backtest = maior quantidade de dados disponível para treino)
dict_results = {
    "MES_REF": [],
    "R2": [],
    "MAPE": [],
    "WMAPE": [],
    "RMSE": [],
    "RMSE_RELATIVO": [],
}

for mes in df_avaliacao['MES_REF'].unique():
    _df = df_avaliacao[df_avaliacao['MES_REF'] == mes].copy()

    r2 = stats.pearsonr(_df['y'], _df['yhat'])[0]**2
    mape, wmape = mape_wmape(_df['y'], _df['yhat'])
    rmse = root_mean_squared_error(_df['y'], _df['yhat'])
    rmse_relativo = rmse / _df['y'].mean()

    dict_results["MES_REF"].append(mes)
    dict_results["R2"].append(r2)
    dict_results["MAPE"].append(mape*100)
    dict_results["WMAPE"].append(wmape*100)
    dict_results["RMSE"].append(rmse)
    dict_results["RMSE_RELATIVO"].append(rmse_relativo)

# %%
df_results_mes_ref = pd.DataFrame(dict_results)
df_results_mes_ref
# Out:
#        MES_REF        R2      MAPE     WMAPE           RMSE  RMSE_RELATIVO
# 0   2018-06-01  0.999088  3.702944  0.000002   51669.251324       0.032392
# 1   2018-12-01  0.998423  3.283186  0.000002   82513.691254       0.048266
# 2   2019-06-01  0.998550  3.158796  0.000002   67881.113197       0.041199
# 3   2019-12-01  0.998841  4.103377  0.000002  111958.414704       0.064889
# 4   2020-06-01  0.997505  5.438637  0.000003  177748.607443       0.100640
# 5   2020-12-01  0.998604  3.745090  0.000002   72837.766089       0.040049
# 6   2021-06-01  0.998271  3.246067  0.000002  119048.635152       0.068157
# 7   2021-12-01  0.995940  3.918664  0.000002  141015.928424       0.077684
# 8   2022-06-01  0.998499  3.046402  0.000002   71464.582437       0.040018
# 9   2022-12-01  0.993909  4.192693  0.000002  157647.734708       0.082746
# 10  2023-06-01  0.995927  7.620469  0.000004  232187.909979       0.117337
# ...

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Métricas de Performance em relação ao mês de backtest', fontsize=16)

df_results_mes_ref.plot(x='MES_REF', y='R2', ax=axes[0, 0], legend=False)
axes[0, 0].set_title('R²')
axes[0, 0].set_ylabel('R²')
axes[0, 0].set_xlabel('Mês Backtest')

df_results_mes_ref.plot(x='MES_REF', y='MAPE', ax=axes[0, 1], legend=False)
axes[0, 1].set_title('MAPE')
axes[0, 1].set_ylabel('MAPE')
axes[0, 1].set_xlabel('Mês Backtest')

df_results_mes_ref.plot(x='MES_REF', y='WMAPE', ax=axes[1, 0], legend=False)
axes[1, 0].set_title('WMAPE')
axes[1, 0].set_ylabel('WMAPE')
axes[1, 0].set_xlabel('Mês Backtest')

df_results_mes_ref.plot(x='MES_REF', y='RMSE', ax=axes[1, 1], legend=False)
axes[1, 1].set_title('RMSE')
axes[1, 1].set_ylabel('RMSE')
axes[1, 1].set_xlabel('Mês Backtest')

df_results_mes_ref.plot(x='MES_REF', y='RMSE_RELATIVO', ax=axes[2, 0], legend=False)
axes[2, 0].set_title('RMSE Relativo')
axes[2, 0].set_ylabel('RMSE Relativo')
axes[2, 0].set_xlabel('Mês Backtest')

# Hide the empty subplot
axes[2, 1].axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
dict_results2 = {
    "MES_PROJECAO": [],
    "R2": [],
    "MAPE": [],
    "WMAPE": [],
    "RMSE": [],
    "RMSE_RELATIVO": [],
}

for mes in df_avaliacao['MES_PROJECAO'].unique():
    _df = df_avaliacao[df_avaliacao['MES_PROJECAO'] == mes].copy()

    r2 = stats.pearsonr(_df['y'], _df['yhat'])[0]**2
    mape, wmape = mape_wmape(_df['y'], _df['yhat'])
    rmse = root_mean_squared_error(_df['y'], _df['yhat'])
    rmse_relativo = rmse / _df['y'].mean()

    dict_results2["MES_PROJECAO"].append(mes)
    dict_results2["R2"].append(r2)
    dict_results2["MAPE"].append(mape*100)
    dict_results2["WMAPE"].append(wmape*100)
    dict_results2["RMSE"].append(rmse)
    dict_results2["RMSE_RELATIVO"].append(rmse_relativo)

# %%
df_results_mes_proj = pd.DataFrame(dict_results2)
df_results_mes_proj
# Out:
#    MES_PROJECAO        R2      MAPE     WMAPE           RMSE  RMSE_RELATIVO
# 0             1  0.995530  3.365761  0.000002  128926.913206       0.072535
# 1             2  0.996658  3.844484  0.000002  107777.486893       0.060832
# 2             3  0.997676  3.903727  0.000002  111928.390178       0.061070
# 3             4  0.994502  4.413896  0.000002  142988.396114       0.078350
# 4             5  0.993939  4.531298  0.000003  148290.923406       0.082212
# 5             6  0.994327  4.919505  0.000003  151535.912129       0.084317

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Métricas de Performance em relação ao mês de backtest', fontsize=16)

df_results_mes_proj.plot(x='MES_PROJECAO', y='R2', ax=axes[0, 0], legend=False)
axes[0, 0].set_title('R²')
axes[0, 0].set_ylabel('R²')
axes[0, 0].set_xlabel('Mês Projetado')

df_results_mes_proj.plot(x='MES_PROJECAO', y='MAPE', ax=axes[0, 1], legend=False)
axes[0, 1].set_title('MAPE')
axes[0, 1].set_ylabel('MAPE')
axes[0, 1].set_xlabel('Mês Projetado')

df_results_mes_proj.plot(x='MES_PROJECAO', y='WMAPE', ax=axes[1, 0], legend=False)
axes[1, 0].set_title('WMAPE')
axes[1, 0].set_ylabel('WMAPE')
axes[1, 0].set_xlabel('Mês Projetado')

df_results_mes_proj.plot(x='MES_PROJECAO', y='RMSE', ax=axes[1, 1], legend=False)
axes[1, 1].set_title('RMSE')
axes[1, 1].set_ylabel('RMSE')
axes[1, 1].set_xlabel('Mês Projetado')

df_results_mes_proj.plot(x='MES_PROJECAO', y='RMSE_RELATIVO', ax=axes[2, 0], legend=False)
axes[2, 0].set_title('RMSE Relativo')
axes[2, 0].set_ylabel('RMSE Relativo')
axes[2, 0].set_xlabel('Mês Projetado')

# Hide the empty subplot
axes[2, 1].axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Projetando o mercado futuro

# %%
dict_consumo_regiao['Nordeste']
# Out:
# 'Nordeste'

# %%
df_projecao = pd.DataFrame()
for regiao in regioes:

    df_serie = dict_consumo_regiao[regiao].copy()

    df_serie = formata_dataframe(df_serie, ds_col="Data", y_col="Consumo")

    modelo_consumo = Prophet(
        growth=model_kwargs["growth"],
        seasonality_mode=model_kwargs["seasonality_mode"],
        yearly_seasonality=model_kwargs["yearly_seasonality"],
    )

    _df_projecao = gera_projecao_6m(
        modelo_consumo,
        df_serie,
        mes_limite='2024-06-01',  # Último mês disponível no histórico
        considera_covid=model_kwargs["considera_covid"],
    )

    _df_projecao['Regiao'] = regiao
    df_projecao = pd.concat([df_projecao, _df_projecao])

    plt.plot(
        df_serie['ds'],
        df_serie['y'],
        label='Real'
    )

    plt.plot(
        _df_projecao['ds'],
        _df_projecao['yhat'],
        label='Projeção',
        linestyle='--'
    )

    plt.legend()
    plt.ylabel('Consumo (MWh)')
    plt.xlabel('Mês-Ano')
    plt.title(f"Projeção de Consumo Residencial - {regiao}")
    plt.show()
# Out:
# 19:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:58 - cmdstanpy - INFO - Chain [1] done processing
# 19:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:58 - cmdstanpy - INFO - Chain [1] done processing
# 19:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:58 - cmdstanpy - INFO - Chain [1] done processing
# 19:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:59 - cmdstanpy - INFO - Chain [1] done processing
# 19:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:59 - cmdstanpy - INFO - Chain [1] done processing
# 19:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 19:24:00 - cmdstanpy - INFO - Chain [1] done processing
# 19:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 19:24:00 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # **Resultados**
#
# ## Resultados gerais
#
# ### Projeções de validação cruzada
#
# *[Gráficos presentes acima]*
#
# ### WMAPE e MAPE
#
# **WMAPE (Weighted Mean Absolute Percentage Error)** e **MAPE (Mean Absolute Percentage Error)** são métricas amplamente utilizadas para avaliar a precisão de modelos de previsão.
#
# - **WMAPE**: O WMAPE é uma variação do MAPE que leva em consideração o peso dos valores reais. Isso ajuda a minimizar a penalidade em meses de baixa demanda, proporcionando uma visão mais equilibrada da precisão do modelo.
#
# - **MAPE**: O MAPE é calculado como a média dos erros absolutos percentuais entre os valores previstos e os valores reais. Ele fornece uma medida clara de quão precisas são as previsões em termos percentuais.
#
# De forma geral, a projeção foi satisfatória, resultando em erros médios absolutos de aproximadamento 0% (ponderado pelo consumo, minimizando penalidades em meses de baixas de mercado) e 4.16%. Contudo, ainda que pareçam erros baixos, a validação dessa hipótese se dará pela conversão do gap de consumo energético não previsto em dinheiro (real ou dólar).
#
# ## Coeficiente de Determinação (R²)
#
# O coeficiente de determinação, R², é uma medida estatística que indica a proporção da variância nos valores dependentes que é previsível a partir dos valores independentes. Em outras palavras, é um indicativo de quão bem os dados projetados se ajustam aos dados reais.
#
# No caso estudado, o valor de R² é 99.52%, o que significa que 99.52% da variância nos valores reais pode ser explicada pelas projeções. Este é um valor razoável, indicando que as projeções têm um bom nível de precisão, mas ainda há espaço para melhorias.
#
# Portanto, com um R² de 99.52%, podemos concluir que as projeções tendem a ser confiáveis, mas melhorias ainda são necessárias para garantir assertividade.
#
# ## Raiz do errro quadrático médio (RMSE)
#
# O RMSE é uma métrica amplamente utilizada para avaliar o desempenho de modelos de regressão, contudo, é sensível a valores extremos, que podem distorcer a métrica.
#
# De modo simplificado, RMSE baixo indica que o modelo tem uma boa precisão, pois os valores previstos estão próximos dos valores reais, por outro lado, RMSE alto indica que o modelo tem uma precisão ruim, pois os valores previstos estão distantes dos valores reais, ou, a projeção contém outliers. Vale ressaltar que o conteito de erro baixo ou alto depende do contexto e escala no qual a métrica será implementada, onde é necessária interpretação do cientista para garantir que o modelo desenvolvido está operando com a eficácia desejada.
#
# Avaliando todas as projeções (períodos de backtest), um RMSE de 133 mil foi obtido, contudo, tal valor representa apenas 7% da média de consumo de energia ao longo dos períodos de teste.
#
# ## Ponderações sobre resultados discretizados
#
# Ao avaliar métricas segundo o mês de backtest, ou seja, projetando para apenas 6 meses ao longo dos semestres passados e aumentando cada vez mais o conjunto de teste disponível, percebe-se o impacto gerado pelo aumento de demanda energética no ano de 2024 (observável nos gráficos comparativos do histórico e projeções), sendo o período no o modelo foi mais impactado negativamente, chegando em valores de MAPE de ~7%. Dito isso, em um âmbito geral, a performance observada inicialmente se manteve, conforme indica a Figura [x1].
#
# ![image.png](attachment:image.png)
#
# Figura [x1] - Performance do modelo em diferentes meses de referência
#
# Avaliando os erros associados a maiores horizontes de projeções, observou-se piora na performance do modelo, fato esperado uma vez que quão mais longe dos dados reais, mais incerta é a previsão.
#
# No que diz respeito aos erros médios, não houve nenhuma variação brusca de performance, mas sim um aumento, em maioria, linear das métricas observadas. Em contrapartida, o aumento do RMSE entre os horizontes de 3 e 4 meses é notório, tendo como provável causa o aumento sazonal entre março (mês de baixa demanda) e abril (mês de alta demanda), conforme ilustra a Figura [x2].
#
# ![image-2.png](attachment:image-2.png)
#
# Figura [x2] - Performance do modelo em diferentes horizontes de projeção

# %% [markdown]
# ## Projeções do mercado futuro
#
#
# Finalmente, baseado nas projeções futuras de mercado, é esperado que o consumo de energia do setor residencial sigam na crescente observada nos últimos anos, fato que está diretamente ligado com a evolução tecnológica e acessibilidade cada vez maior a dispositivos eletrônicos e eletrodomésticos que garantem praticidade na vida das pessoas.
# Vale ressaltar que para as regiões Centro-Oeste, Sul e Sudeste, são esperados picos de consumo em menores magnetudes do que observado no ano de 2024.

# %% [markdown]
# # **Discussão e Conclusão**
#
# [Interir Texto]

# %% [markdown]
# # Apresentação
#
# [Adicionar Link do vídeo](https://www.youtube.com/)

# %% [markdown]
# # **Referências**
#
# FONTES DE ENERGIA. Disponível em: <https://www.epe.gov.br/pt/abcdenergia/fontes-de-energia>. Acesso em: 3 set. 2024.
#
# Brasil é referência no campo da energia limpa e renovável. Disponível em: <https://www.gov.br/pt-br/noticias/energia-minerais-e-combustiveis/2021/10/brasil-e-referencia-no-campo-da-energia-limpa-e-renovavel>. Acesso em: 4 set. 2024.
#
# Brasil registra participação de mais de 90% de energia proveniente de fontes renováveis. Disponível em<https://www.ons.org.br/Paginas/Noticias/20230331_Brasil_registra_participacao_de_mais_de_90_de_energia_proveniente_de_fontes_renovaveis-.aspx>. Acesso em: 4 set. 2024.
#
# Dados do Consumo Mensal de Energia Elétrica. Disponível em: <https://www.epe.gov.br/pt/publicacoes-dados-abertos/dados-abertos/dados-do-consumo-mensal-de-energia-eletrica>. Acesso em: 4 set. 2024.
#
# Bem vindo - ONS DADOS ABERTOS. Disponível em: <https://dados.ons.org.br/>. Acesso em: 4 set. 2024.
#
# Capacidade Instalada de Geração - ONS DADOS ABERTOS. Disponível em: <https://dados.ons.org.br/dataset/capacidade-geracao>. Acesso em: 4 set. 2024.
#
# Bem vindo - Dados Abertos - Agência Nacional de Energia Elétrica. Disponível em: <https://dadosabertos.aneel.gov.br/>. Acesso em: 4 set. 2024
#
# INDGER - Indicadores Gerenciais da Distribuição - Dados Abertos - Agência Nacional de Energia Elétrica. Disponível em: <https://dadosabertos.aneel.gov.br/dataset/indger-indicadores-gerenciais-da-distribuicao>. Acesso em: 4 set. 2024.
#
# WHITNEY, J.; MENDONÇA, M. UNIVERSIDADE FEDERAL DA PARAÍBA CENTRO DE ENERGIAS ALTERNATIVAS E RENOVÁVEIS DEPARTAMENTO DE ENGENHARIA ELÉTRICA. (WHITNEY; MENDONÇA, 2022). Disponível em: <https://www.cear.ufpb.br/juan/wp-content/uploads/2023/04/2022-Desenvolvimento-de-um-Modelo-de-Previsao-de-Demanda-de-Energia-Baseado-em-Algoritmos-de-Inteligencia-Artificial-de-Curto-Prazo.pdf>. Acesso em: 26 set. 2024.
#
# IFTIKHAR, H. et al. Electricity Demand Forecasting Using a Novel Time Series Ensemble Technique. IEEE Access, v. 12, p. 88963–88975, 2024.
#
# ‌ALEGRE, P. UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL FACULDADE DE CIÊNCIAS ECONÔMICAS DEPARTAMENTO DE ECONOMIA E RELAÇÕES INTERNACIONAIS MATHEUS VIZZOTTO DOS SANTOS PROJEÇÃO DE DEMANDA ELÉTRICA COM ALGORITMOS DE APRENDIZADO DE MÁQUINA. [s.l: s.n.]. Disponível em: <https://lume.ufrgs.br/bitstream/handle/10183/252159/001154419.pdfbd3dfa74b36824fed2fe391ffd84b869MD5110183/2521592022-12-02?sequence=1>. Acesso em: 27 set. 2024.

# %%
#@title **Avaliação**
EDA_e_preprocessamento = 10 #@param {type:"slider", min:0, max:10, step:1}
Modelo_base = 10 #@param {type:"slider", min:0, max:10, step:1}
Revisao = 10 #@param {type:"slider", min:0, max:10, step:1}
Apresentacao_geral = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.4*EDA_e_preprocessamento + 0.2*Modelo_base + 0.2*Revisao + 0.2*Apresentacao_geral

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 10.0
#                               nome  nota
# 0        Daniel Rodrigues da Silva  10.0
# 1       João Pedro Barreto de Melo  10.0
# 2         Julia Rodrigues da Cunha  10.0
# 3      Rafael Rodrigues Nascimento  10.0
# 4  Samuel Regis Nascimento Barbosa  10.0
